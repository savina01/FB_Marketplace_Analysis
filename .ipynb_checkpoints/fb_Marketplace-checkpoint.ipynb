# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Visualization Properties
sns.set_theme(style="whitegrid")
plt.rcParams['figure.figsize'] = (12, 6)

# Loading dataset
data_path = 'facebook_marketplace_data.csv'

data = pd.read_csv(data_path)

data
# Out:
#                                                   Link  \
# 0    https://www.facebook.com/marketplace/np/item/1...
# 1    https://www.facebook.com/marketplace/np/item/5...
# 2    https://www.facebook.com/marketplace/np/item/8...
# 3    https://www.facebook.com/marketplace/np/item/1...
# 4    https://www.facebook.com/marketplace/np/item/1...
# ..                                                 ...
# 207  https://www.facebook.com/marketplace/np/item/8...
# 208  https://www.facebook.com/marketplace/np/item/1...
# 209  https://www.facebook.com/marketplace/np/item/1...
# 210  https://www.facebook.com/marketplace/np/item/2...
# 211  https://www.facebook.com/marketplace/np/item/5...
#
#                                              Photo Url        Price  \
# 0    https://scontent.fsof4-1.fna.fbcdn.net/v/t39.3...  160 000 лв.
# 1    https://scontent.fsof4-1.fna.fbcdn.net/v/t45.5...      180 лв.
# 2    https://scontent.fsof4-1.fna.fbcdn.net/v/t39.3...  125 000 лв.
# 3    https://scontent.fsof4-1.fna.fbcdn.net/v/t39.3...  139 500 лв.
# 4    https://scontent.fsof4-1.fna.fbcdn.net/v/t39.3...  128 960 лв.
# ..                                                 ...          ...
# 207  https://scontent.fsof4-1.fna.fbcdn.net/v/t45.5...      150 лв.
# 208  https://scontent.fsof4-1.fna.fbcdn.net/v/t39.3...  106 000 лв.
# 209  https://scontent.fsof4-1.fna.fbcdn.net/v/t45.5...       95 лв.
# 210  https://scontent.fsof4-1.fna.fbcdn.net/v/t39.3...  205 000 лв.
# 211  https://scontent.fsof4-1.fna.fbcdn.net/v/t45.5...       17 лв.
#
#                                              Name             City
# 0                                      Апартамент        Botevgrad
# 1       Lorelli бебешко легло 60/120см matrix new  София, България
# 2     Продавам къща в село Миланово област София.            Своге
# 3                              Къща в с. Костенец        Kostenets
# 4                   Двустаен апартамент в Надежда  София, България
# ..                                            ...              ...
# 207  Фритюрник 5 л. Bereket \nС чугунена горелка.       Kyustendil
# 208         Продава апаратамент в Малинова долина  София, България
# 209                   Премиум ПВЦ мраморни панели  София, България
# 210        Двустаен апартамент в кв.Кръстова вада  София, България
# 211       Knauf Perlfix, Ceresit Thermo Universal  София, България
#
# [212 rows x 5 columns]

# %%
print(data.dtypes)
# Out:
# Link         object
# Photo Url    object
# Price        object
# Name         object
# City         object
# dtype: object

# %%
data.rename(columns={'Name': 'Title'}, inplace=True)

# %%
print("Check for missing values:")
print(data.isnull().sum())
# Out:
# Check for missing values:
# Link         0
# Photo Url    0
# Price        0
# Title        0
# City         0
# dtype: int64

# %%
print("Check for NaN values:")
print(data.isna().sum())
# Out:
# Check for NaN values:
# Link         0
# Photo Url    0
# Price        0
# Title        0
# City         0
# dtype: int64

# %%
print("Checking for infinite values:")
print((data == float('inf')).sum())
# Out:
# Checking for infinite values:
# Link         0
# Photo Url    0
# Price        0
# Title        0
# City         0
# dtype: int64

# %%
data.dtypes
# Out:
# Link         object
# Photo Url    object
# Price        object
# Title        object
# City         object
# dtype: object

# %%
# Price cleanup
def clean_price(price_str):
    # Remove "лв.", commas, etc.
    price_str = price_str.replace(' лв.', '').replace(' ', '').replace(',', '')

    try:
        return float(price_str)
    except ValueError:
        # In case we cannot convert, return NaN
        return np.nan

# %%
# Cities cleanup
cyrillic_to_latin = {
    'а': 'a', 'б': 'b', 'в': 'v', 'г': 'g', 'д': 'd',
    'е': 'e', 'ж': 'zh', 'з': 'z', 'и': 'i', 'й': 'y',
    'к': 'k', 'л': 'l', 'м': 'm', 'н': 'n', 'о': 'o',
    'п': 'p', 'р': 'r', 'с': 's', 'т': 't', 'у': 'u', 
    'ф': 'f', 'х': 'h', 'ц': 'ts', 'ч': 'ch', 'ш': 'sh',
    'щ': 'sht', 'ъ': 'a', 'ь': 'y', 'ю': 'yu', 'я': 'ya'
}

data['City'] = data['City'].str.replace('България', '').str.strip()
data['City'] = data['City'].str.replace('Bulgaria', '').str.strip()
data['City'] = data['City'].str.replace(',', '')
data['City'] = data['City'].str.lower()

for key in cyrillic_to_latin.keys():
    data['City'] = data['City'].str.replace(key, cyrillic_to_latin[key])

data['City'] = data['City'].str.capitalize()

data['City']
# Out:
# 0       Botevgrad
# 1          Sofiya
# 2           Svoge
# 3       Kostenets
# 4          Sofiya
#           ...
# 207    Kyustendil
# 208        Sofiya
# 209        Sofiya
# 210        Sofiya
# 211        Sofiya
# Name: City, Length: 212, dtype: object

# %%
# --- Data Cleanup ---

# Remove rows with missing Price or City data
data = data.dropna(subset=['Price', 'City'])

# Character cleanup
data['Price'] = data['Price'].replace(r'[^\d]', '', regex=True)

# Numeric convertion
data['Price'] = pd.to_numeric(data['Price'], errors='coerce')

# %%
from collections import Counter
import re

# Remove leading and following whitespace
data['Title'] = data['Title'].str.strip()

# Text conversion into lowercase and unnecessary symbols removal
data['Title'] = data['Title'].str.lower().apply(lambda x: re.sub(r'[^\w\s]', '', x))

# Splitting the text into words and creating a list
all_words = ' '.join(data['Title'].tolist()).split()

# Word frequency
word_counts = Counter(all_words)

# Sort by frequency
common_words = word_counts.most_common()

print("Top 10 most frequently used words in the 'Title' column:")
for word, count in common_words[:10]:
    print(f"{word}: {count}")
# Out:
# Top 10 most frequently used words in the 'Title' column:
# в: 93
# апартамент: 69
# къща: 40
# тристаен: 38
# с: 36
# на: 33
# двустаен: 27
# продавам: 23
# кв: 20
# софия: 17

# %%
# Zipping the words and their frequency
words, counts = zip(*common_words[:10])

# Bar plot creation
plt.figure(figsize=(12, 8))
sns.barplot(x=list(counts), y=list(words), hue=list(words), palette='viridis')
plt.xlabel('Frequency')
plt.ylabel('Words')
plt.title("Top 10 most frequently used words in the 'Title' column")
plt.show()

# %%
data
# Out:
#                                                   Link  \
# 0    https://www.facebook.com/marketplace/np/item/1...
# 1    https://www.facebook.com/marketplace/np/item/5...
# 2    https://www.facebook.com/marketplace/np/item/8...
# 3    https://www.facebook.com/marketplace/np/item/1...
# 4    https://www.facebook.com/marketplace/np/item/1...
# ..                                                 ...
# 207  https://www.facebook.com/marketplace/np/item/8...
# 208  https://www.facebook.com/marketplace/np/item/1...
# 209  https://www.facebook.com/marketplace/np/item/1...
# 210  https://www.facebook.com/marketplace/np/item/2...
# 211  https://www.facebook.com/marketplace/np/item/5...
#
#                                              Photo Url   Price  \
# 0    https://scontent.fsof4-1.fna.fbcdn.net/v/t39.3...  160000
# 1    https://scontent.fsof4-1.fna.fbcdn.net/v/t45.5...     180
# 2    https://scontent.fsof4-1.fna.fbcdn.net/v/t39.3...  125000
# 3    https://scontent.fsof4-1.fna.fbcdn.net/v/t39.3...  139500
# 4    https://scontent.fsof4-1.fna.fbcdn.net/v/t39.3...  128960
# ..                                                 ...     ...
# 207  https://scontent.fsof4-1.fna.fbcdn.net/v/t45.5...     150
# 208  https://scontent.fsof4-1.fna.fbcdn.net/v/t39.3...  106000
# 209  https://scontent.fsof4-1.fna.fbcdn.net/v/t45.5...      95
# 210  https://scontent.fsof4-1.fna.fbcdn.net/v/t39.3...  205000
# 211  https://scontent.fsof4-1.fna.fbcdn.net/v/t45.5...      17
#
#                                           Title        City
# 0                                    апартамент   Botevgrad
# 1      lorelli бебешко легло 60120см matrix new      Sofiya
# 2    продавам къща в село миланово област софия       Svoge
# 3                             къща в с костенец   Kostenets
# 4                 двустаен апартамент в надежда      Sofiya
# ..                                          ...         ...
# 207  фритюрник 5 л bereket \nс чугунена горелка  Kyustendil
# 208       продава апаратамент в малинова долина      Sofiya
# 209                 премиум пвц мраморни панели      Sofiya
# 210       двустаен апартамент в квкръстова вада      Sofiya
# 211      knauf perlfix ceresit thermo universal      Sofiya
#
# [212 rows x 5 columns]

# %%
# Adding item type based on the title 
def classify_item(name):
    if 'апартамент' in name.lower():
        return 'Apartment'
    elif 'къща' in name.lower():
        return 'House'
    elif 'легло' in name.lower():
        return 'Bed'
    else:
        return 'Others'

data['Item Type'] = data['Title'].apply(classify_item)

# %%
data
# Out:
#                                                   Link  \
# 0    https://www.facebook.com/marketplace/np/item/1...
# 1    https://www.facebook.com/marketplace/np/item/5...
# 2    https://www.facebook.com/marketplace/np/item/8...
# 3    https://www.facebook.com/marketplace/np/item/1...
# 4    https://www.facebook.com/marketplace/np/item/1...
# ..                                                 ...
# 207  https://www.facebook.com/marketplace/np/item/8...
# 208  https://www.facebook.com/marketplace/np/item/1...
# 209  https://www.facebook.com/marketplace/np/item/1...
# 210  https://www.facebook.com/marketplace/np/item/2...
# 211  https://www.facebook.com/marketplace/np/item/5...
#
#                                              Photo Url   Price  \
# 0    https://scontent.fsof4-1.fna.fbcdn.net/v/t39.3...  160000
# 1    https://scontent.fsof4-1.fna.fbcdn.net/v/t45.5...     180
# 2    https://scontent.fsof4-1.fna.fbcdn.net/v/t39.3...  125000
# 3    https://scontent.fsof4-1.fna.fbcdn.net/v/t39.3...  139500
# 4    https://scontent.fsof4-1.fna.fbcdn.net/v/t39.3...  128960
# ..                                                 ...     ...
# 207  https://scontent.fsof4-1.fna.fbcdn.net/v/t45.5...     150
# 208  https://scontent.fsof4-1.fna.fbcdn.net/v/t39.3...  106000
# 209  https://scontent.fsof4-1.fna.fbcdn.net/v/t45.5...      95
# 210  https://scontent.fsof4-1.fna.fbcdn.net/v/t39.3...  205000
# 211  https://scontent.fsof4-1.fna.fbcdn.net/v/t45.5...      17
#
#                                           Title        City  Item Type
# 0                                    апартамент   Botevgrad  Apartment
# 1      lorelli бебешко легло 60120см matrix new      Sofiya        Bed
# 2    продавам къща в село миланово област софия       Svoge      House
# 3                             къща в с костенец   Kostenets      House
# 4                 двустаен апартамент в надежда      Sofiya  Apartment
# ..                                          ...         ...        ...
# 207  фритюрник 5 л bereket \nс чугунена горелка  Kyustendil     Others
# 208       продава апаратамент в малинова долина      Sofiya     Others
# 209                 премиум пвц мраморни панели      Sofiya     Others
# 210       двустаен апартамент в квкръстова вада      Sofiya  Apartment
# 211      knauf perlfix ceresit thermo universal      Sofiya     Others
#
# [212 rows x 6 columns]

# %%
data.dtypes
# Out:
# Link         object
# Photo Url    object
# Price         int64
# Title        object
# City         object
# Item Type    object
# dtype: object

# %%
# --- Data Analysis ---

# Price Distribution
plt.figure()
sns.histplot(data['Price'], bins=20, kde=True, color='blue')
plt.title('Price Distribution')
plt.xlabel('Price in thousands of leva')
plt.ylabel('Frequency')
plt.show()

# %%
city_counts = data['City'].value_counts() 

plt.figure(figsize=(10, 6))
sns.barplot(x=city_counts.index, y=city_counts.values, hue=city_counts.index, dodge=False, palette='viridis', legend=False)
plt.title('Number of ads per city') 
plt.xlabel('City')
plt.ylabel('Number of ads')
plt.xticks(rotation=90)
plt.show()

# %%
# Average price by City (top 10 cities)
mean_prices_by_city = data.groupby('City')['Price'].mean().sort_values(ascending=False).head(10)

plt.figure(figsize=(10, 6))
sns.barplot(x=mean_prices_by_city.values, y=mean_prices_by_city.index, hue=mean_prices_by_city.index, palette='viridis')
plt.title('Average price by City (Top 10)', fontsize=14)
plt.xlabel('Average price (lv.)', fontsize=12)
plt.ylabel('City', fontsize=12)
plt.show()

# %%
item_type_counts = data['Item Type'].value_counts()

plt.figure(figsize=(8, 8))
plt.pie(item_type_counts, labels=item_type_counts.index, autopct='%1.1f%%', colors=sns.color_palette('pastel'))
plt.title('Distribution of property types')
plt.show()

# %%
# Pivot table for average price of ads per city and property type
pivot_table = data.pivot_table(values='Price', index='City', columns='Item Type', aggfunc='mean')

# Heat map
plt.figure(figsize=(12, 8))
sns.heatmap(pivot_table, annot=True, fmt=".2f", cmap='YlGnBu')
plt.title('Heat map of the average price of ads per city and ad type')
plt.xlabel('Ad type')
plt.ylabel('City')
plt.show()

# %%
# Групиране на данните по Item Type и изчисляване на средната цена за всяка група
grouped_data = data.groupby('Item Type')['Price'].mean().reset_index()

# Визуализация на средната цена спрямо Item Type
plt.figure(figsize=(10, 6))
sns.barplot(x='Item Type', y='Price', hue='Item Type', data=grouped_data, palette='viridis', legend=False)
plt.title('Average price for item')
plt.xlabel('Item type')
plt.ylabel('Average price')
plt.xticks(rotation=45)
plt.show()
